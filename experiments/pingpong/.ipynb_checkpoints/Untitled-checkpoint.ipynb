# %%
import os
import re
dir = './results_after_grpc_era_c07/'
pattern = re.compile(r"results_ping_pong_sync_atomics_7x[0-9]+")
files = [f for f in os.listdir(dir) if pattern.match(f)]
values = {}
for f in files:
    split = f.split('x')
    num_clients = int(split[1])
    f = open(dir + f, "r")
    p50 = 0
    qps = 0
    for line in f:
        if "p50" in line:
            p50 = int(re.search(r'value: \d+', line).group().removeprefix("value: "))
        if "qps" in line:
            qps = int(re.search(r' \d+', line).group().lstrip())
    values[num_clients] = (p50, qps)
for key in sorted(values):
    print("num clients %d p50 %d qps %d" % (key, values[key][0], values[key][1]))
# Out:
# num clients 1 p50 71 qps 13792
# num clients 2 p50 86 qps 21904
# num clients 4 p50 164 qps 23159
# num clients 5 p50 212 qps 22114
# num clients 6 p50 254 qps 22393
# num clients 8 p50 346 qps 21734
# num clients 10 p50 436 qps 21457
# num clients 12 p50 526 qps 21396
# num clients 14 p50 609 qps 21410
# num clients 16 p50 699 qps 21404
# num clients 18 p50 793 qps 21027
# num clients 20 p50 874 qps 21088
# num clients 50 p50 14486 qps 2761
# num clients 100 p50 60551 qps 1601

# %%
import matplotlib.pyplot as plt

x_values = [values[key][1] for key in sorted(values) if key < 50]
y_values = [values[key][0] for key in sorted(values) if key < 50]
print(x_values)
print(y_values)
plt.xlabel("queries per second")
plt.ylabel("p50 latency in μs")
plt.title('Measurements on dm-c07 for ping pong with protobuf without grpc with synchronization with clients on 7 servers dm-c01 to dm-c07 and the server on dm-c08')
plt.plot(x_values, y_values)
# Out:
# [13792, 21904, 23159, 22114, 22393, 21734, 21457, 21396, 21410, 21404, 21027, 21088]
# [71, 86, 164, 212, 254, 346, 436, 526, 609, 699, 793, 874]
