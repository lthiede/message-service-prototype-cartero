# %%
import os
import re
dir = './results_16_cores_c07/'
pattern = re.compile(r"results_ping_pong_16_cores_7x[0-9]+")
files = [f for f in os.listdir(dir) if pattern.match(f)]
values = {}
for f in files:
    split = f.split('x')
    num_clients = int(split[1])
    f = open(dir + f, "r")
    p50 = 0
    qps = 0
    for line in f:
        if "p50" in line:
            p50 = int(re.search(r'value: \d+', line).group().removeprefix("value: "))
        if "qps" in line:
            qps = int(re.search(r' \d+', line).group().lstrip())
    values[num_clients] = (p50, qps)
for key in sorted(values):
    print("num cores %d p50 %d qps %d" % (key, values[key][0], values[key][1]))
# Out:
# num cores 1 p50 1120 qps 11281
# num cores 2 p50 454 qps 23009
# num cores 4 p50 257 qps 40397
# num cores 8 p50 156 qps 70442
# num cores 16 p50 131 qps 83002
# num cores 32 p50 140 qps 74265

# %%
import matplotlib.pyplot as plt

x_values = [key for key in sorted(values)]
y_values = [values[key][1] for key in sorted(values) if key < 50]
print(x_values)
print(y_values)
plt.xlabel("cores")
plt.ylabel("queries per second")
plt.title('Measurements on dm-c07 for ping pong with 12 clients per client node')
plt.plot(x_values, y_values)
plt.xscale('log')
plt.xticks(ticks=x_values, labels=x_values)
plt.ylim(ymin=0)
# Out:
# [1, 2, 4, 8, 16, 32]
# [11281, 23009, 40397, 70442, 83002, 74265]
# (0.0, 86588.05)
